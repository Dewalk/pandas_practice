# %%
import pandas as pd
import statsmodels.formula.api as smf
import seaborn as sns
import numpy as np

uni_df = pd.read_csv('/Users/galvanize/PANDAS-REPOS/university_data/DATA/universities.csv')

# %%
uni_df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
uni_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
uni_df.describe()
# Out:
#                Size
# count    2829.00000
# mean     4374.88123
# std      9256.38326
# min         4.00000
# 25%       493.00000
# 50%      1478.00000
# 75%      4064.00000
# max    301323.00000

# %%
uni_df.head()
# Out:
#                                       name  \
# 0  A T Still University of Health Sciences
# 1             Abilene Christian University
# 2     Abraham Baldwin Agricultural College
# 3                          Academy College
# 4     Academy for Five Element Acupuncture
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# 3  1101 E. 78th Street, Suite 100, Minneapolis, M...  www.academycollege.edu
# 4         305 SE 2nd Ave, Gainesville, Florida 32601   www.acupuncturist.edu
#
#                                                 Type    Size
# 0                     4-year, Private not-for-profit  3480.0
# 1                     4-year, Private not-for-profit  4669.0
# ...

# %%
raw = pd.read_csv('/Users/galvanize/PANDAS-REPOS/university_data/DATA/universities.csv')
raw
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
raw.shape
# Out:
# (2907, 5)

# %%
web_nulls = raw['Website'].isna()
raw[web_nulls]
# Out:
#                             name  \
# 134               Atenas College
# 161        Bais Binyomin Academy
# 162           Bais Medrash Elyon
# 163    Bais Medrash Toras Chesed
# 209   Beis Medrash Heichal Dovid
# ...                          ...
# 2897          Yeshivas Novominsk
# 2898     Yeshivat Mikdash Melech
# 2899        Yeshivath Beth Moshe
# 2900           Yeshivath Viznitz
# 2901     Yeshivath Zichron Moshe
#
#                                                 address Website  \
# 134   Paseo de La Atenas  #101, Manati, Puerto Rico ...     NaN
# 161        132 Prospect St, Stamford, Connecticut 06901     NaN
# 162                  73 Main St, Monsey, New York 10952     NaN
# 163        901 Monmouth Ave, Lakewood, New Jersey 08701     NaN
# 209     257 Beach 17th St, Far Rockaway, New York 11691     NaN
# ...                                                 ...     ...
# 2897         1690 60th Street, Brooklyn, New York 11204     NaN
# ...

# %%
raw = raw.drop(['Website'], axis=1)

# %%
size_nulls = raw['Size'].isna()
raw[size_nulls]
# Out:
#                                         name  \
# 38          Alliant International University
# 39          Alliant International University
# 40          Alliant International University
# 42          Alliant International University
# 43          Alliant International University
# ...                                      ...
# 2753     Washington State University-Spokane
# 2754  Washington State University-Tri Cities
# 2755   Washington State University-Vancouver
# 2801             Western Seminary-Sacramento
# 2802               Western Seminary-San Jose
#
#                                                 address  \
# 38    One Beach Street, Suite 100, San Francisco, Ca...
# 39    2500 Michelson Dr-Ste 250, Irvine, California ...
# 40    2595 Capital Oaks Drive, Suite 200, Sacramento...
# 42    5130 E Clinton Way, Fresno, California 93727-1360
# 43    1000 S Fremont Ave, Unit 5, Alhambra, Californ...
# ...                                                 ...
# ...

# %%
size_median = round(raw['Size'].median())
size_median
# Out:
# 1478.0

# %%
raw['Size'] = raw['Size'].fillna(size_median)

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Type     2907 non-null   object
#  3   Size     2907 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 91.0+ KB

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Type     2907 non-null   object
#  3   Size     2907 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 91.0+ KB

# %%
raw.describe()
# Out:
#                 Size
# count    2907.000000
# mean     4297.152735
# std      9143.307911
# min         4.000000
# 25%       509.500000
# 50%      1478.000000
# 75%      3934.500000
# max    301323.000000

# %% [markdown]
# find both the mean and median size by each university type (as given in the dataframe),
# ordered by average size in ascending order

# %%
raw.groupby('Type').describe()
# Out:
#                                                       Size                \
#                                                      count          mean
# Type
# 4-year, Private for-profit                           284.0   3397.468310
# 4-year, Private not-for-profit                      1579.0   2371.861305
# 4-year, Public                                       618.0  11236.173139
# 4-year, primarily associate's, Private for-profit    268.0    934.380597
# 4-year, primarily associate's, Private not-for-...    87.0   1129.413793
# 4-year, primarily associate's, Public                 71.0   6889.366197
#
#                                                                          \
#                                                              std    min
# Type
# 4-year, Private for-profit                          18694.334062   12.0
# 4-year, Private not-for-profit                       3861.421549    4.0
# 4-year, Public                                      10897.957851   40.0
# ...

# %%
raw_mean = round(raw.groupby('Type').mean()).sort_values(by='Size', ascending=True)
raw_mean
# Out:
#                                                        Size
# Type
# 4-year, primarily associate's, Private for-profit     934.0
# 4-year, primarily associate's, Private not-for-...   1129.0
# 4-year, Private not-for-profit                       2372.0
# 4-year, Private for-profit                           3397.0
# 4-year, primarily associate's, Public                6889.0
# 4-year, Public                                      11236.0

# %%
raw_median = raw.groupby('Type').median()

# %%
raw_median
# Out:
#                                                       Size
# Type
# 4-year, Private for-profit                           788.5
# 4-year, Private not-for-profit                      1290.0
# 4-year, Public                                      7461.5
# 4-year, primarily associate's, Private for-profit    564.5
# 4-year, primarily associate's, Private not-for-...   768.0
# 4-year, primarily associate's, Public               3558.0

# %%
type_info = raw.groupby('Type').aggregate([np.mean, np.median]).reset_index()
#type_info['Size']['median']
type_info
# Out:
#                                                 Type          Size
#                                                               mean  median
# 0                         4-year, Private for-profit   3397.468310   788.5
# 1                     4-year, Private not-for-profit   2371.861305  1290.0
# 2                                     4-year, Public  11236.173139  7461.5
# 3  4-year, primarily associate's, Private for-profit    934.380597   564.5
# 4  4-year, primarily associate's, Private not-for...   1129.413793   768.0
# 5              4-year, primarily associate's, Public   6889.366197  3558.0

# %% [markdown]
# Make new columns  in the dataframe from existing data for the following attributes:
# City
# State
# ZipCode
# Private or Public
# for-profit or not-for-profit
# primarily associate's (1 for Yes, 0 for No)

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Type     2907 non-null   object
#  3   Size     2907 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 91.0+ KB

# %%
addresses = raw['address']
addresses = addresses.str.split(',')
#add = raw['Address'].spilt(',')
zipc = []
state = []
city = []
street_address = []
suite_apt = []


for i in range(len(addresses)):
        state_zip = addresses[i][-1].split()
        zipc.append(state_zip[1])
        state.append(state_zip[0])
        city.append(addresses[i][-2])
        street = addresses[i][0].split(',')
        #print(street)
        street_address.append(street[0])
        #print(addresses[i])
    
   
# for address in addresses:
#     if len(address) > 4:
#         print(address)
# #addresses[3]

# %%
#raw['Zip Code'][1000]
#raw['State']
# zipc
# state
# city
# street_address

# %%
raw['Zip Code'] = zipc
raw['State'] = state
raw['City'] = city
#len(street_address)
raw['Street Address'] = street_address

# %%
raw
raw = raw.drop('address', axis=1)
raw = raw[['name','Street Address','City', 'State','Zip Code','Type','Size']]

# %%
raw
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                      Street Address          City          State    Zip Code  \
# 0                   800 W Jefferson    Kirksville       Missouri       63501
# 1                 1600 Campus Court       Abilene          Texas       79699
# ...

# %% [markdown]
# Using the new columns you've made above (and excluding the original type column), find both the mean and median size of each university by State, by Private or Public, and by whether the university is primarily associate's or not.

# %%
uni_types = raw['Type'].value_counts()
#uni_types = raw['Type']
uni_types
# Out:
# 4-year, Private not-for-profit                           1579
# 4-year, Public                                            618
# 4-year, Private for-profit                                284
# 4-year, primarily associate's, Private for-profit         268
# 4-year, primarily associate's, Private not-for-profit      87
# 4-year, primarily associate's, Public                      71
# Name: Type, dtype: int64

# %%
raw['Private'] = raw['Type'].str.contains('Private',case=True)
raw['Primarily Associates'] = raw['Type'].str.contains('primarily', case=True)
raw['Profit'] = raw['Type'].str.contains(' for-profit', case=True)

# %%
raw
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                      Street Address          City          State    Zip Code  \
# 0                   800 W Jefferson    Kirksville       Missouri       63501
# 1                 1600 Campus Court       Abilene          Texas       79699
# ...

# %%
yes_no = [raw['Private']==1, raw['Private']==0]
one_zeros = ['Private', 'Public']
raw['Private'] = np.select(yes_no, one_zeros)

# %%
is_profit = [raw['Profit']==True, raw['Profit']==False]
options = ['For-Profit','Not-for-Profit']
raw['Profit'] = np.select(is_profit, options)

# %%
assoc = [raw['Primarily Associates']==True, raw['Primarily Associates']==False]
yes_no = ['Yes', 'No']
raw['Primarily Associates'] = np.select(assoc, yes_no)

# %%
raw
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                      Street Address          City          State    Zip Code  \
# 0                   800 W Jefferson    Kirksville       Missouri       63501
# 1                 1600 Campus Court       Abilene          Texas       79699
# ...

# %%
raw['Primarily Associates'].value_counts()
# Out:
# No     2481
# Yes     426
# Name: Primarily Associates, dtype: int64

# %%
#privates = np.where(raw['Private']==1)
is_private = raw['Private']=='Private'
#priv = raw[is_private]
#type(privates)
is_private
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 2902     True
# 2903     True
# 2904     True
# 2905    False
# 2906     True
# Name: Private, Length: 2907, dtype: bool

# %%
#grouped.aggregate(np.mean).loc[:,'age']
#raw.groupby('State')

# %%
#students_df.groupby(['studgender', 'studmaritalstatus'])['SATscore'].mean() #.iloc[0] #['D']
#students_df.loc[(students_df.studgender=='F') & (students_df.studstate=='WA')]
#raw.groupby('State')['Size'].mean()
states = raw.groupby('State')
#pri = raw.groupby('Private')
prv = raw.loc[(raw['Private']=='Private') & raw['Size']]
# state_size_mean = round(states.aggregate(np.mean).loc[:,'Size'])
#state_size_mean
prv.groupby('State').mean()
# Out:
#                       Size
# State
# Alabama        2162.034483
# Alaska          775.000000
# Arizona        9673.763158
# Arkansas       1134.133333
# California     1790.925581
# Colorado       2214.111111
# Connecticut    2741.217391
# Delaware       3479.000000
# District       8041.133333
# Florida        2199.157025
# Georgia        1865.490196
# Guam            149.000000
# Hawaii         1723.111111
# Idaho          2658.000000
# Illinois       2743.641509
# Indiana        1683.734375
# Iowa           2942.840909
# Kansas          917.758621
# Kentucky       1260.189189
# Louisiana      2040.600000
# Maine          1483.166667
# Maryland       2063.333333
# Massachusetts  3122.116279
# Michigan       1984.957746
# Minnesota      2340.723077
# Mississippi    1281.090909
# Missouri       2151.770270
# Montana         945.750000
# Nebraska       1322.086957
# Nevada          961.444444
# New            2663.182927
# North          1614.419355
# Ohio           1822.209877
# ...

# %%
# for i in range(len(types)):
#     raw['Category'] = types[0][1]

# %%
# raw['Category']
# #raw['Category'].value_counts()
# raw['Category'].tail()

# %% [markdown]
# Use the tools you've learned to compute at least one other aggregate from the dataset Save the updated dataframe as a csv (using the pandas to_csv method) and commit your files, and push up to github.
